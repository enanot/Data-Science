# %%
import pandas as pd

# %%
data = pd.read_csv('37630.csv',sep='\t')
data
# Out:
#     Comunidades Autónomas             Tipo de dato  Periodo    Total
# 0          Total Nacional                   Índice     2022  113,233
# 1          Total Nacional                   Índice     2021  107,377
# 2          Total Nacional                   Índice     2020  105,169
# 3          Total Nacional                   Índice     2019   105,77
# 4          Total Nacional                   Índice     2018  105,262
# ..                    ...                      ...      ...      ...
# 535          17 Rioja, La  Tasa de variación anual     2012     -2,7
# 536          17 Rioja, La  Tasa de variación anual     2011     -0,6
# 537          17 Rioja, La  Tasa de variación anual     2010      1,1
# 538          17 Rioja, La  Tasa de variación anual     2009      0,2
# 539          17 Rioja, La  Tasa de variación anual     2008       ..
#
# [540 rows x 4 columns]

# %%
data_cat = data
data_cat = data_cat[data_cat["Comunidades Autónomas"] == '09 Cataluña']
data_cat
#new_df = new_df[new_df.order_id < 7]
# Out:
#     Comunidades Autónomas             Tipo de dato  Periodo    Total
# 270           09 Cataluña                   Índice     2022  114,033
# 271           09 Cataluña                   Índice     2021  108,166
# 272           09 Cataluña                   Índice     2020  106,585
# 273           09 Cataluña                   Índice     2019  106,756
# 274           09 Cataluña                   Índice     2018   106,27
# 275           09 Cataluña                   Índice     2017  100,388
# 276           09 Cataluña                   Índice     2016      100
# 277           09 Cataluña                   Índice     2015  100,416
# 278           09 Cataluña                   Índice     2014   98,775
# 279           09 Cataluña                   Índice     2013    98,58
# 280           09 Cataluña                   Índice     2012   99,164
# 281           09 Cataluña                   Índice     2011  100,477
# 282           09 Cataluña                   Índice     2010  102,359
# ...

# %%
pd.set_option('display.max_rows',None)
data
# Out:
#               Comunidades Autónomas             Tipo de dato  Periodo    Total
# 0                    Total Nacional                   Índice     2022  113,233
# 1                    Total Nacional                   Índice     2021  107,377
# 2                    Total Nacional                   Índice     2020  105,169
# 3                    Total Nacional                   Índice     2019   105,77
# 4                    Total Nacional                   Índice     2018  105,262
# 5                    Total Nacional                   Índice     2017   99,694
# 6                    Total Nacional                   Índice     2016      100
# 7                    Total Nacional                   Índice     2015   100,19
# 8                    Total Nacional                   Índice     2014   99,529
# 9                    Total Nacional                   Índice     2013   98,559
# 10                   Total Nacional                   Índice     2012   98,985
# ...
