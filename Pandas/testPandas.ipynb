# %% [markdown]
# ### Introducción a la biblioteca Pandas

# %%
import pandas as pd, numpy as np

# %% [markdown]
# Pandas sirve para trabajar con dataFrames, hacer analisis con datos,

# %% [markdown]
# Importamos datos de un fichero de texto plano CSV

# %%
data = pd.read_csv('./data/mexican.tsv',sep='\t')

# %% [markdown]
# Imprimo las 10 primeras lineas de mi dataframe

# %%
data.head(3)
# Out:
#    Unnamed: 0  order_id  quantity                     item_name  \
# 0           0         1         1  Chips and Fresh Tomato Salsa
# 1           1         1         1                          Izze
# 2           2         1         1              Nantucket Nectar
#
#   choice_description item_price
# 0                NaN     $2.39
# 1       [Clementine]     $3.39
# 2            [Apple]     $3.39

# %% [markdown]
# Ver la estructura del dataframe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  3376 non-null   object
#  5   item_price          4622 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 216.8+ KB

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# Como importar a un archvo

# %%
data.to_csv('./data/backup.csv',sep = ';')

# %% [markdown]
# ##  Como ordenar los datos

# %%
data.item_name.sort_values(ascending=False).head(20)
# Out:
# 3889    Veggie Soft Tacos
# 2851    Veggie Soft Tacos
# 738     Veggie Soft Tacos
# 1395    Veggie Soft Tacos
# 2384    Veggie Soft Tacos
# 1699    Veggie Soft Tacos
# 781     Veggie Soft Tacos
# 4573    Veggie Salad Bowl
# 455     Veggie Salad Bowl
# 496     Veggie Salad Bowl
# 2156    Veggie Salad Bowl
# 2683    Veggie Salad Bowl
# 3293    Veggie Salad Bowl
# 295     Veggie Salad Bowl
# 4109    Veggie Salad Bowl
# 2269    Veggie Salad Bowl
# 1316    Veggie Salad Bowl
# 2223    Veggie Salad Bowl
# 4541    Veggie Salad Bowl
# 3223    Veggie Salad Bowl
# Name: item_name, dtype: object

# %% [markdown]
# mas ordenacion de datos, filtrado de datos

# %%
data.item_name=="Izze"
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 4617    False
# 4618    False
# 4619    False
# 4620    False
# 4621    False
# Name: item_name, Length: 4622, dtype: bool

# %%
data[data.item_name =="Izze"]
# Out:
#       Unnamed: 0  order_id  quantity item_name choice_description item_price
# 1              1         1         1      Izze       [Clementine]     $3.39
# 24            24        12         1      Izze       [Grapefruit]     $3.39
# 47            47        21         1      Izze       [Blackberry]     $3.39
# 66            66        30         1      Izze       [Blackberry]     $3.39
# 359          359       155         1      Izze       [Blackberry]     $3.39
# 360          360       155         1      Izze       [Grapefruit]     $3.39
# 430          430       186         1      Izze       [Grapefruit]     $3.39
# 579          579       237         1      Izze       [Clementine]     $3.39
# 580          580       237         1      Izze       [Grapefruit]     $3.39
# 1059        1059       436         1      Izze       [Clementine]     $3.39
# 1213        1213       495         1      Izze       [Clementine]     $3.39
# ...

# %%
new_df=data[['choice_description','item_name','quantity','item_price']]

new_df
# Out:
#                                      choice_description  \
# 0                                                   NaN
# 1                                          [Clementine]
# 2                                               [Apple]
# 3                                                   NaN
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# ...                                                 ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
#
#                                   item_name  quantity item_price
# 0              Chips and Fresh Tomato Salsa         1     $2.39
# 1                                      Izze         1     $3.39
# 2                          Nantucket Nectar         1     $3.39
# ...

# %%
new_df = new_df[new_df.item_name =='Izze']

new_df
# Out:
#      choice_description item_name  quantity item_price
# 1          [Clementine]      Izze         1     $3.39
# 24         [Grapefruit]      Izze         1     $3.39
# 47         [Blackberry]      Izze         1     $3.39
# 66         [Blackberry]      Izze         1     $3.39
# 359        [Blackberry]      Izze         1     $3.39
# 360        [Grapefruit]      Izze         1     $3.39
# 430        [Grapefruit]      Izze         1     $3.39
# 579        [Clementine]      Izze         1     $3.39
# 580        [Grapefruit]      Izze         1     $3.39
# 1059       [Clementine]      Izze         1     $3.39
# 1213       [Clementine]      Izze         1     $3.39
# 1611       [Blackberry]      Izze         1     $3.39
# 1612       [Blackberry]      Izze         1     $3.39
# 1680       [Clementine]      Izze         1     $3.39
# 2088       [Clementine]      Izze         1     $3.39
# 2619       [Clementine]      Izze         1     $3.39
# ...

# %%
new_df.to_json('./izze.json',orient="records")

# %%
print((new_df.item_price))
# Out:
# 1       $3.39
# 24      $3.39
# 47      $3.39
# 66      $3.39
# 359     $3.39
# 360     $3.39
# 430     $3.39
# 579     $3.39
# 580     $3.39
# 1059    $3.39
# 1213    $3.39
# 1611    $3.39
# 1612    $3.39
# 1680    $3.39
# 2088    $3.39
# 2619    $3.39
# 2634    $3.39
# 2758    $3.39
# 2891    $3.39
# 3669    $3.39
# Name: item_price, dtype: object

# %%
col_sum = (data.quantity*data.item_price) 
col_sum
# Out:
# 0               $2.39
# 1               $3.39
# 2               $3.39
# 3               $2.39
# 4       $16.98 $16.98
#              ...
# 4617           $11.75
# 4618           $11.75
# 4619           $11.25
# 4620            $8.75
# 4621            $8.75
# Length: 4622, dtype: object

# %% [markdown]
# Para insertar/aplicar una funcion una funcion
#
# Es CallBack

# %%
def dolar_to_float(x):
    return float(x[1:])

new_df
# Out:
#      choice_description item_name  quantity item_price
# 1          [Clementine]      Izze         1     $3.39
# 24         [Grapefruit]      Izze         1     $3.39
# 47         [Blackberry]      Izze         1     $3.39
# 66         [Blackberry]      Izze         1     $3.39
# 359        [Blackberry]      Izze         1     $3.39
# 360        [Grapefruit]      Izze         1     $3.39
# 430        [Grapefruit]      Izze         1     $3.39
# 579        [Clementine]      Izze         1     $3.39
# 580        [Grapefruit]      Izze         1     $3.39
# 1059       [Clementine]      Izze         1     $3.39
# 1213       [Clementine]      Izze         1     $3.39
# 1611       [Blackberry]      Izze         1     $3.39
# 1612       [Blackberry]      Izze         1     $3.39
# 1680       [Clementine]      Izze         1     $3.39
# 2088       [Clementine]      Izze         1     $3.39
# 2619       [Clementine]      Izze         1     $3.39
# ...

# %%
#new_df.item_price = new_df.item_price.apply(dolar_to_float)
new_df.item_price = new_df.item_price.apply(lambda x : float(x[1:]))

new_df
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_5284\1976214604.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.item_price = new_df.item_price.apply(lambda x : float(x[1:]))
#      choice_description item_name  quantity  item_price
# 1          [Clementine]      Izze         1        3.39
# 24         [Grapefruit]      Izze         1        3.39
# 47         [Blackberry]      Izze         1        3.39
# 66         [Blackberry]      Izze         1        3.39
# 359        [Blackberry]      Izze         1        3.39
# 360        [Grapefruit]      Izze         1        3.39
# 430        [Grapefruit]      Izze         1        3.39
# 579        [Clementine]      Izze         1        3.39
# ...
