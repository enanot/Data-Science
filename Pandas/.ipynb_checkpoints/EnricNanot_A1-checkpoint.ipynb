# %% [markdown]
# ### Trabajo grupo3 version E.N.

# %% [markdown]
# Importamos librerias necesarias

# %%
import pandas as pd

# %% [markdown]
# Realizamos la carga de datos en la variable data

# %%
data = pd.read_csv('./data/9689_filtred.csv',sep=';')
data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7904 entries, 0 to 7903
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Provincias                7904 non-null   object
#  1   Grupo quinquenal de edad  7904 non-null   object
#  2   Nacionalidad              7904 non-null   object
#  3   Sexo                      7904 non-null   object
#  4   Periodo                   7904 non-null   object
#  5   Total                     7904 non-null   object
# dtypes: object(6)
# memory usage: 370.6+ KB

# %%
data.iloc[%2==0]
# Out:
#   Cell In[261], line 1
#     data.iloc[%2==0]
#               ^
# SyntaxError: invalid syntax

# %%
data_fil = data["enero" in str(data.Periodo)]
data_fil
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[255], line 1
# ----> 1 data_fil= data["enero" in str(data.Periodo)]
#       2 data_fil
#
# ...

# %% [markdown]
# Mostramos las diez primeras columnas

# %%
data_male= data[data.Sexo == "Hombres"]

data_female = data[data.Sexo == "Mujeres"]

print("--------------------")
data_female
# Out:
# --------------------
#        Provincias Grupo quinquenal de edad Nacionalidad     Sexo  \
# 4     02 Albacete            De 0 a 4 años     Española  Mujeres
# 5     02 Albacete            De 0 a 4 años     Española  Mujeres
# 6     02 Albacete            De 0 a 4 años     Española  Mujeres
# 7     02 Albacete            De 0 a 4 años     Española  Mujeres
# 12    02 Albacete            De 5 a 9 años     Española  Mujeres
# ...           ...                      ...          ...      ...
# 7895   52 Melilla          De 85 a 89 años     Española  Mujeres
# 7900   52 Melilla            90 y más años     Española  Mujeres
# 7901   52 Melilla            90 y más años     Española  Mujeres
# 7902   52 Melilla            90 y más años     Española  Mujeres
# 7903   52 Melilla            90 y más años     Española  Mujeres
#
#                  Periodo         Total
# 4     1 de julio de 2022  6.195,000000
# 5     1 de enero de 2022  6.353,000000
# 6     1 de julio de 2019  7.088,918340
# ...

# %%
data_male
# Out:
#        Provincias Grupo quinquenal de edad Nacionalidad     Sexo  \
# 0     02 Albacete            De 0 a 4 años     Española  Hombres
# 1     02 Albacete            De 0 a 4 años     Española  Hombres
# 2     02 Albacete            De 0 a 4 años     Española  Hombres
# 3     02 Albacete            De 0 a 4 años     Española  Hombres
# 8     02 Albacete            De 5 a 9 años     Española  Hombres
# ...           ...                      ...          ...      ...
# 7891   52 Melilla          De 85 a 89 años     Española  Hombres
# 7896   52 Melilla            90 y más años     Española  Hombres
# 7897   52 Melilla            90 y más años     Española  Hombres
# 7898   52 Melilla            90 y más años     Española  Hombres
# 7899   52 Melilla            90 y más años     Española  Hombres
#
#                  Periodo         Total
# 0     1 de julio de 2022  6.683,000000
# 1     1 de enero de 2022  6.877,000000
# 2     1 de julio de 2019  7.773,172848
# ...

# %% [markdown]
# Identificamos el tipo de dato,
# Primera columna: Provincias, String;
# Segunda columna: Grupo, String:
# Tercera columna: Nacionalidad String;
# Cuarta columna: Sexo, String;
# Quinta columna: Periodo, String;
# Sexta columna: Total, Float;

# %% [markdown]
# Calculos por poblacion total
# La media, mediana, desviación estándar, y valores mínimo y máximo de las siguientes variables:
